# %%
import pandas as pd
import numpy as np

# %%
studens_performance = pd.read_csv('csv/StudentsPerformance.csv')

# %%
studens_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
studens_performance.head(4)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44

# %%
studens_performance.tail(4)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
studens_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
studens_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
studens_performance.shape
# Out:
# (1000, 8)

# %%
studens_performance.groupby('gender').aggregate({'math score' : 'mean'})
# Out:
#         math score
# gender
# female   63.633205
# male     68.728216

# %%
studens_performance.size
# Out:
# 8000

# %%
studens_performance.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
studens_performance.iloc[0:5, [1,4,-1]]
# Out:
#   race/ethnicity test preparation course  writing score
# 0        group B                    none             74
# 1        group C               completed             88
# 2        group B                    none             93
# 3        group A                    none             44
# 4        group C                    none             75

# %%
names = studens_performance.iloc[[1,23,4,5,56,3]]

# %%
names.index = ['Vika', 'Masha', 'Sasha', 'Liza', 'Ulya', 'Kirill']

# %%
names
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# Vika    female        group C                some college      standard
# Masha   female        group C            some high school      standard
# Sasha     male        group C                some college      standard
# Liza    female        group B          associate's degree      standard
# Ulya    female        group E          associate's degree      standard
# Kirill    male        group A          associate's degree  free/reduced
#
#        test preparation course  math score  reading score  writing score
# Vika                 completed          69             90             88
# Masha                     none          69             73             73
# Sasha                     none          76             78             75
# Liza                      none          71             83             78
# Ulya                 completed          82             85             86
# ...

# %%
names.loc[['Vika','Sasha','Liza']]
# Out:
#        gender race/ethnicity parental level of education     lunch  \
# Vika   female        group C                some college  standard
# Sasha    male        group C                some college  standard
# Liza   female        group B          associate's degree  standard
#
#       test preparation course  math score  reading score  writing score
# Vika                completed          69             90             88
# Sasha                    none          76             78             75
# Liza                     none          71             83             78

# %%
names.loc[['Vika','Sasha','Liza'], ['test preparation course', 'math score']]
# Out:
#       test preparation course  math score
# Vika                completed          69
# Sasha                    none          76
# Liza                     none          71

# %%
names.iloc[:,0]
# Out:
# Vika      female
# Masha     female
# Sasha       male
# Liza      female
# Ulya      female
# Kirill      male
# Name: gender, dtype: object

# %%
names['gender']
# Out:
# Vika      female
# Masha     female
# Sasha       male
# Liza      female
# Ulya      female
# Kirill      male
# Name: gender, dtype: object

# %%
names[['gender']]
# Out:
#         gender
# Vika    female
# Masha   female
# Sasha     male
# Liza    female
# Ulya    female
# Kirill    male

# %%
type(names.iloc[:,0])
# Out:
# pandas.core.series.Series

# %%
series_1 = pd.Series([1,2,3], ['Vika','Sasha','Liza'])
series_2 = pd.Series([4,5,6], ['Vika','Sasha','Liza'])

# %%
pd.DataFrame({'column_1':series_1, 'column_2':series_2})
# Out:
#        column_1  column_2
# Vika          1         4
# Sasha         2         5
# Liza          3         6

# %%
names.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')
