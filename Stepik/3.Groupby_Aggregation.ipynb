# %%
import pandas as pd 
import numpy as np

# %%
stud = pd.read_csv('csv/StudentsPerformance.csv')

# %%
stud
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
group = stud.groupby(['gender', 'race/ethnicity']) \
.aggregate({'math score' : 'mean', 'reading score' : 'var', 'writing score' : 'std'}) \
.rename(columns = {'math score' : 'mean_math_score', 'reading score' : 'var_reading_score', 'writing score' : \
                   'std_writing_score'})

# %%
stud.groupby(['gender', 'race/ethnicity'], as_index=False) \
.aggregate({'math score' : 'mean', 'reading score' : 'var', 'writing score' : 'std'}) \
.rename(columns = {'math score' : 'mean_math_score', 'reading score' : 'var_reading_score', 'writing score' : \
                   'std_writing_score'})
# Out:
#    gender race/ethnicity  mean_math_score  var_reading_score  \
# 0  female        group A        58.527778         220.457143
# 1  female        group B        61.403846         213.528006
# 2  female        group C        62.033333         193.225947
# 3  female        group D        65.248062         193.622820
# 4  female        group E        70.811594         235.606564
# 5    male        group A        63.735849         238.736575
# 6    male        group B        65.930233         215.965116
# 7    male        group C        67.611511         176.666354
# 8    male        group D        69.413534         162.966393
# 9    male        group E        76.746479         195.068410
#
#    std_writing_score
# 0          14.652455
# 1          14.891439
# 2          14.806595
# 3          13.866814
# 4          15.703671
# 5          15.137061
# 6          14.854907
# 7          13.647341
# 8          13.262574
# 9          13.449885

# %%
group
# Out:
#                        mean_math_score  var_reading_score  std_writing_score
# gender race/ethnicity
# female group A               58.527778         220.457143          14.652455
#        group B               61.403846         213.528006          14.891439
#        group C               62.033333         193.225947          14.806595
#        group D               65.248062         193.622820          13.866814
#        group E               70.811594         235.606564          15.703671
# male   group A               63.735849         238.736575          15.137061
#        group B               65.930233         215.965116          14.854907
#        group C               67.611511         176.666354          13.647341
#        group D               69.413534         162.966393          13.262574
#        group E               76.746479         195.068410          13.449885

# %%
group.loc[('male', 'group A')]
# Out:
# mean_math_score       63.735849
# var_reading_score    238.736575
# std_writing_score     15.137061
# Name: (male, group A), dtype: float64

# %%
group.loc['male']
# Out:
#                 mean_math_score  var_reading_score  std_writing_score
# race/ethnicity
# group A               63.735849         238.736575          15.137061
# group B               65.930233         215.965116          14.854907
# group C               67.611511         176.666354          13.647341
# group D               69.413534         162.966393          13.262574
# group E               76.746479         195.068410          13.449885

# %%
stud.groupby(['race/ethnicity', 'gender']) \
.aggregate({'math score' : 'mean', 'reading score' : 'var', 'writing score' : 'std'})
# Out:
#                        math score  reading score  writing score
# race/ethnicity gender
# group A        female   58.527778     220.457143      14.652455
#                male     63.735849     238.736575      15.137061
# group B        female   61.403846     213.528006      14.891439
#                male     65.930233     215.965116      14.854907
# group C        female   62.033333     193.225947      14.806595
#                male     67.611511     176.666354      13.647341
# group D        female   65.248062     193.622820      13.866814
#                male     69.413534     162.966393      13.262574
# group E        female   70.811594     235.606564      15.703671
#                male     76.746479     195.068410      13.449885

# %%
group.loc[[('female', 'group A'), ('male', 'group E')]]
# Out:
#                        mean_math_score  var_reading_score  std_writing_score
# gender race/ethnicity
# female group A               58.527778         220.457143          14.652455
# male   group E               76.746479         195.068410          13.449885

# %%
stud['math score'].unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8])

# %%
# count by unique values in this column
stud['math score'].nunique()
# Out:
# 81

# %%
stud.groupby(['gender', 'race/ethnicity'])['math score'].nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math score, dtype: int64

# %%
# top 5 men and women in math
# ascending - reverse
stud.sort_values(['gender', 'math score'], ascending=False) \
.groupby('gender').head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 149               completed         100            100             93
# ...

# %%
stud.sort_values(['gender', 'math score']) \
.groupby('gender').head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# 91     male        group C                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 76     male        group E            some high school      standard
# 596    male        group B                 high school  free/reduced
# 211    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 59                     none           0             17             10
# ...

# %%
# New columns
stud['total_score'] = stud['math score'] + stud['reading score'] + stud['writing score']

# %%
stud = stud.assign(total_score_log = np.log(stud.total_score), total_score_mean = stud.total_score/3)

# %%
stud
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
stud.sort_values(['gender', 'total_score_mean'], ascending=False) \
.groupby('gender').head(4)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 916    male        group E           bachelor's degree      standard
# 625    male        group D                some college      standard
# 149    male        group E          associate's degree  free/reduced
# 381    male        group C          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 179  female        group D            some high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 916               completed         100            100            100
# 625               completed         100             97             99
# 149               completed         100            100             93
# ...

# %%
#Delete column
stud.drop('total_score_log', axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
