# %%
import pandas as pd 
import numpy as np

# %%
stud = pd.read_csv("csv/StudentsPerformance.csv")

# %%
stud.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
stud.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
stud.loc[stud.gender == 'male']
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
stud.loc[stud["test preparation course"] == "completed", ["math score","reading score","writing score"]]
# Out:
#      math score  reading score  writing score
# 1            69             90             88
# 6            88             95             92
# 8            64             64             67
# 13           78             72             70
# 18           46             42             46
# ..          ...            ...            ...
# 990          86             81             75
# 991          65             82             78
# 995          88             99             95
# 997          59             71             65
# 998          68             78             77
#
# [358 rows x 3 columns]

# %%
stud[(stud["race/ethnicity"] == "group A") & (stud["parental level of education"] == "high school")]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 143    male        group A                 high school      standard
# 170    male        group A                 high school      standard
# 395    male        group A                 high school  free/reduced
# 467    male        group A                 high school  free/reduced
# 468  female        group A                 high school  free/reduced
# 483    male        group A                 high school      standard
# 506    male        group A                 high school      standard
# 586  female        group A                 high school      standard
# 635    male        group A                 high school      standard
# 651  female        group A                 high school      standard
# 688    male        group A                 high school  free/reduced
# 811    male        group A                 high school  free/reduced
# 837  female        group A                 high school      standard
# ...
